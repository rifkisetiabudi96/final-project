# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt

# %%
# Loading audio files
sample1_file = "F:/DIV TRM AP I/KULIAH SEMESTER 4/SKRIPSI RIFKI/FINALPROJECTWEB/audio/01.wav"
sample2_file = "F:/DIV TRM AP I/KULIAH SEMESTER 4/SKRIPSI RIFKI/FINALPROJECTWEB/audio/02.wav"
sample3_file = "F:/DIV TRM AP I/KULIAH SEMESTER 4/SKRIPSI RIFKI/FINALPROJECTWEB/audio/03.wav"

# %%
# load audio files with librosa
sample1, sl = librosa.load(sample1_file)

# %%
# Mel filter banks
filter_banks = librosa.filters.mel(n_fft=2048, sr=22050, n_mels=10)

# %%
# Analyze Filter Banks Shape
filter_banks.shape
# Out:
# (10, 1025)

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(filter_banks, 
                         sr=sl, 
                         x_axis="linear")
plt.colorbar(format="%+2.f")
plt.show()

# %%
# Extracting Mel Spectrogram
mel_spectrogram = librosa.feature.melspectrogram(sample1, sr=sl, n_fft=2048, hop_length=512, n_mels=10)
mel_spectrogram.shape
# Out:
# (10, 596)

# %%
log_mel_spectrogram = librosa.power_to_db(mel_spectrogram)

# %%
log_mel_spectrogram.shape
# Out:
# (10, 596)

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(log_mel_spectrogram, 
                         x_axis="time",
                         y_axis="mel", 
                         sr=sl)
plt.colorbar(format="%+2.f")
plt.show(block=False)
